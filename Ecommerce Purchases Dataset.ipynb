# %%
import pandas as pd

# %%
ecomm_data = pd.read_csv('Ecommerce Purchases')
ecomm_data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # 1. Display Top 10 rows of the Dataset

# %%
ecomm_data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# # 2. Display last 10 rows of the Dataset

# %%
ecomm_data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# # 3. DIsplay n number of random sample data from the Dataset

# %%
ecomm_data.sample(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 7362                 USCGC Rodriguez\nFPO AP 12191-3474  62 Wd       PM
# 7951       3033 Taylor Lakes\nNew Travisshire, WY 60848  41 MY       PM
# 219                           USNS Levine\nFPO AP 68420  64 Bx       AM
# 9541          446 Timothy Key\nKarenview, HI 44383-2240  46 lS       PM
# 1784  104 George Vista Apt. 124\nSouth Shelley, NJ 0...  00 ay       AM
# 3922  181 Paul Prairie Apt. 845\nBrandonburgh, LA 78...  33 vC       AM
# 7167     04331 Lauren Garden\nRachelside, PR 14939-9211  09 Yb       PM
# 862      252 Joshua Run Suite 919\nDavismouth, MS 55287  72 tt       AM
# 5320  989 Fisher Rapids Suite 523\nNew Stevenmouth, ...  70 la       PM
# 8762              Unit 1228 Box 2625\nDPO AP 32412-1817  44 kX       AM
#
#                                            Browser Info  \
# 7362  Mozilla/5.0 (X11; Linux i686) AppleWebKit/5351...
# 7951  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_5_8...
# ...

# %% [markdown]
# # 4. Check datatype of each column in a Dataset

# %%
ecomm_data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# # 5. Display overall statistical description of the Dataset

# %%
ecomm_data.describe(include='all')
# Out:
#                                                   Address    Lot AM or PM  \
# count                                               10000  10000    10000
# unique                                              10000   9822        2
# top     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  16 gc       PM
# freq                                                    1      2     5068
# mean                                                  NaN    NaN      NaN
# std                                                   NaN    NaN      NaN
# min                                                   NaN    NaN      NaN
# 25%                                                   NaN    NaN      NaN
# 50%                                                   NaN    NaN      NaN
# 75%                                                   NaN    NaN      NaN
# max                                                   NaN    NaN      NaN
#
#                                              Browser Info    Company  \
# ...

# %% [markdown]
# # 6. Display the no.of rows and no. of columns in a Dataset

# %%
len(ecomm_data.columns)
# Out:
# 14

# %%
len(ecomm_data)
# Out:
# 10000

# %%
ecomm_data.shape
# Out:
# (10000, 14)

# %% [markdown]
# # 7. Check null values in the Dataset

# %%
ecomm_data.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
ecomm_data.isnull().sum() #provides the sum of null values
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
ecomm_data.isnull().any()
# Out:
# Address             False
# Lot                 False
# AM or PM            False
# Browser Info        False
# Company             False
# Credit Card         False
# CC Exp Date         False
# CC Security Code    False
# CC Provider         False
# Email               False
# Job                 False
# IP Address          False
# Language            False
# Purchase Price      False
# dtype: bool

# %% [markdown]
# # 8. Check duplicate value in Dataset

# %%
ecomm_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
ecomm_data.duplicated().any()
# Out:
# False

# %% [markdown]
# # 9. Find the highest and the lowest purchse price.

# %%
ecomm_data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecomm_data['Purchase Price'].max()
# Out:
# 99.99

# %%
ecomm_data['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# # 10. Find the average of Purchse Price

# %%
ecomm_data['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# # 11. How many people have frech 'fr' as their language

# %%
ecomm_data['Language']
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
ecomm_data['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %%
len(ecomm_data[ecomm_data['Language']=='fr'])
# Out:
# 1097

# %%
len(ecomm_data[ecomm_data['Language'].str.contains('fr')])
# Out:
# 1097

# %% [markdown]
# # 12. Data/List of Job Title containing engineer.

# %%
ecomm_data[ecomm_data['Job'].str.contains('Engineer', case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(ecomm_data[ecomm_data['Job'].str.contains('Engineer')])
# Out:
# 453

# %% [markdown]
# # 13. Find email of the person with the following IP address: 132.207.160.22

# %%
ecomm_data[ecomm_data['IP Address']=='132.207.160.22']
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
ecomm_data[ecomm_data['IP Address']=='132.207.160.22'][['Email','IP Address']]
# Out:
#                             Email      IP Address
# 2  amymiller@morales-harrison.com  132.207.160.22

# %% [markdown]
# # 14. How many people have master card as their credit card provider and made a purchase above 50

# %%
ecomm_data[ecomm_data['CC Provider']=='Mastercard']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
# ...                                                 ...    ...      ...
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
ecomm_data[ecomm_data['Purchase Price'] > 50]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# ...                                                 ...    ...      ...
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecomm_data[(ecomm_data['CC Provider'].str.contains('Mastercard')) & (ecomm_data['Purchase Price'] > 50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(ecomm_data[(ecomm_data['CC Provider'].str.contains('Mastercard')) & (ecomm_data['Purchase Price'] > 50)])
# Out:
# 405

# %% [markdown]
# # 15. How many people have master card as their credit card provider or made a purchase above 50

# %%
len(ecomm_data[(ecomm_data['CC Provider'].str.contains('Mastercard')) | (ecomm_data['Purchase Price'] > 50)])
# Out:
# 5463

# %% [markdown]
# # 16. Find email of the person with the following credit card number: 4664825258997302

# %%
ecomm_data[ecomm_data['Credit Card']==4664825258997302][['Email', 'Credit Card']]
# Out:
#                   Email       Credit Card
# 9992  bberry@wright.net  4664825258997302

# %% [markdown]
# # 17. How many people purchase during the AM and How many purchase during PM?

# %%
purchase_time = ecomm_data['AM or PM'].value_counts()
purchase_time
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
print('The total number of people purchasing during AM is', purchase_time['AM'])
print('The total number of people purchasing during PM is', purchase_time['PM'])
# Out:
# The total number of people purchasing during AM is 4932
# The total number of people purchasing during PM is 5068

# %% [markdown]
# # 18. How many people have a credit card that expires in 2020?

# %%
ecomm_data['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
def fun():
    count = 0
    for date in ecomm_data['CC Exp Date']:
        if date.split('/')[1] == '20':
            count += 1
            
    print(count)
    
fun()
# Out:
# 988

# %%
len(ecomm_data[ecomm_data['CC Exp Date'].apply(lambda x:x[3:]=='20')])
# Out:
# 988

# %%
sum(ecomm_data['CC Exp Date'].apply(lambda x:x[3:]=='20'))
# Out:
# 988

# %% [markdown]
# # 19. What are the top 5 most popular email providers(eg. gmail.com, yahoo.com, etc...)

# %%
ecomm_data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecomm_data['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
email = []
for mail in ecomm_data['Email']:
    email.append(mail.split('@')[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 email = []
# ----> 2 for mail in ecomm_data['Email']:
#       3     email.append(mail.split('@')[1])
#
# NameError: name 'ecomm_data' is not defined

# %%
ecomm_data['Email Provider'] = email
ecomm_data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecomm_data.insert(10,'Email1',email)

# %%
ecomm_data['Email Provider'].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email Provider, dtype: int64

# %%
ecomm_data.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
#how many engineers are using  mozzilla browsers to purchase
# which browser is mostly used.
# which ccprovider is hijghly used.

# %% [markdown]
# # 20. How many engineers are using mozilla browser to purchase

# %%
# retrieving the columns of the dataset
ecomm_data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Email1',
#        'Job', 'IP Address', 'Language', 'Purchase Price', 'Email Provider'],
#       dtype='object')

# %%
# retrieving the records of persons who have job as Engineer or engineer from the dataset
ecomm_data[ecomm_data['Job'].str.contains('Engineer', case = False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
# retrieving the records of persons who use Mozilla/mozilla browser from the dataset
ecomm_data[ecomm_data['Browser Info'].str.contains('Mozilla', case = False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# retrieving the lists/records of Engineer/engineer who use Mozilla/mozilla browser to purchase from the dataset
ecomm_data[(ecomm_data['Job'].str.contains('Engineer', case = False)) & (ecomm_data['Browser Info'].str.contains('Mozilla', case = False))]
# Out:
#                                                 Address    Lot AM or PM  \
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 64    937 Weaver Isle Apt. 096\nTracyborough, KY 182...  97 QO       AM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9945    693 Gomez Keys\nWest Marcushaven, SC 32366-3890  60 tG       PM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
#finding the total number of Engineer/engineer who use Mozilla/mozilla browser to purchase from the dataset
len(ecomm_data[(ecomm_data['Job'].str.contains('Engineer', case = False)) & (ecomm_data['Browser Info'].str.contains('Mozilla', case = False))])
# Out:
# 786

# %% [markdown]
# # 21. Find out which browser is the mostly used.

# %%
ecomm_data['Browser Info'].value_counts().head()
#ecomm_data['Browser Info'].value_counts().sort_values()
#the .value_counts() returns the count of unique elements of a column in descending order by default
# so if we use the method .sort_values(), it provides the result in ascending order.
# Out:
# Mozilla/5.0 (compatible; MSIE 9.0; Windows CE; Trident/4.1)         12
# Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.2; Trident/3.1)     12
# Mozilla/5.0 (compatible; MSIE 5.0; Windows NT 6.0; Trident/3.0)     12
# Mozilla/5.0 (compatible; MSIE 9.0; Windows 95; Trident/4.1)         12
# Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 5.01; Trident/5.0)    11
# Name: Browser Info, dtype: int64

# %%
ecomm_data['Browser Info'].mode() #the mode() method returns the most repetative element within a column.
# Out:
# 0    Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...
# 1    Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# 2    Mozilla/5.0 (compatible; MSIE 9.0; Windows 95;...
# 3    Mozilla/5.0 (compatible; MSIE 9.0; Windows CE;...
# Name: Browser Info, dtype: object

# %%
ecomm_data['Browser Info'].value_counts().idxmax()
# value_counts() method will first get the frequency count of each unique value 
# and then we can retrieve the most frequent value using the idxmax() method.
# Out:
# 'Mozilla/5.0 (compatible; MSIE 9.0; Windows CE; Trident/4.1)'

# %% [markdown]
# # 22. Which CC Provider is highly used.

# %%
ecomm_data['CC Provider'].value_counts()
# Out:
# JCB 16 digit                   1716
# VISA 16 digit                  1715
# JCB 15 digit                    868
# American Express                849
# Maestro                         846
# Voyager                         829
# Discover                        817
# Mastercard                      816
# VISA 13 digit                   777
# Diners Club / Carte Blanche     767
# Name: CC Provider, dtype: int64

# %%
ecomm_data['CC Provider'].value_counts().idxmax()
# Out:
# 'JCB 16 digit'

# %%
data = pd.DataFrame(ecomm_data['Browser Info'])
data
# Out:
#                                            Browser Info
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1     Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2     Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# ...                                                 ...
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
# [10000 rows x 1 columns]
